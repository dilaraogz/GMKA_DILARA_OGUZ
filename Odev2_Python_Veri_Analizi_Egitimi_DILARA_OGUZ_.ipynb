# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraogz/GMKA_DILARA_OGUZ/blob/main/Odev2_Python_Veri_Analizi_Egitimi_DILARA_OGUZ_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Güney Marmara ve TRAI
# # <center> Python Veri Analizi Eğitimi
# # <center> Ödev 2

# %% [markdown]
# ### BIST30 Endeksinin incelenmesi

# %% [markdown]
# 1. <i> Yahoo Finance</i> sitesinden 2021 yılına ait BIST30 endeks değerlerini indiriniz

# %%
# !pip install yfinance
import yfinance as yf
import plotly.express as px




B30 = yf.download('XU100.IS',start='2021-01-01', end='2021-12-31' )
B30
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/dist-packages (0.2.18)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.3.7)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from yfinance) (40.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-01-04  1482.199951  1500.000000  1478.699951  1495.400024  1495.400024
# 2021-01-05  1492.199951  1506.900024  1474.800049  1489.599976  1489.599976
# 2021-01-06  1501.599976  1509.500000  1497.099976  1505.400024  1505.400024
# 2021-01-07  1511.599976  1522.699951  1505.699951  1522.199951  1522.199951
# 2021-01-08  1526.500000  1542.800049  1519.800049  1540.599976  1540.599976
# ...                 ...          ...          ...          ...          ...
# 2021-12-24  1820.699951  1891.300049  1808.900024  1891.300049  1891.300049
# 2021-12-27  1898.699951  1942.500000  1873.300049  1897.099976  1897.099976
# 2021-12-28  1913.300049  1916.199951  1830.900024  1850.500000  1850.500000
# 2021-12-29  1847.300049  1901.500000  1828.599976  1895.500000  1895.500000
# 2021-12-30  1916.300049  1923.699951  1860.699951  1863.699951  1863.699951
#
#                 Volume
# Date
# 2021-01-04  5172334300
# 2021-01-05  6659180300
# 2021-01-06  5330873300
# 2021-01-07  6175892400
# 2021-01-08  5500828100
# ...                ...
# 2021-12-24  2530669100
# 2021-12-27  3014802700
# 2021-12-28  2584687100
# 2021-12-29  2570994300
# 2021-12-30  2341048300
#
# [247 rows x 6 columns]

# %% [markdown]
# 2. Veriyi özet metotları ile inceleyiniz (head, info, describe)

# %%
B30.info()

B30.describe()

B30.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 247 entries, 2021-01-04 to 2021-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       247 non-null    float64
#  1   High       247 non-null    float64
#  2   Low        247 non-null    float64
#  3   Close      247 non-null    float64
#  4   Adj Close  247 non-null    float64
#  5   Volume     247 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.5 KB
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-01-04  1482.199951  1500.000000  1478.699951  1495.400024  1495.400024
# 2021-01-05  1492.199951  1506.900024  1474.800049  1489.599976  1489.599976
# 2021-01-06  1501.599976  1509.500000  1497.099976  1505.400024  1505.400024
# 2021-01-07  1511.599976  1522.699951  1505.699951  1522.199951  1522.199951
# 2021-01-08  1526.500000  1542.800049  1519.800049  1540.599976  1540.599976
#
#                 Volume
# Date
# 2021-01-04  5172334300
# 2021-01-05  6659180300
# 2021-01-06  5330873300
# 2021-01-07  6175892400
# 2021-01-08  5500828100

# %% [markdown]
# 3. Veri temizleme:<br>
# 	• Tabloda sadece "Adj Close" (düzeltilmiş kapanış) sütununu bırakınız.<br>
# 	• "Adj Close" sütununu " Kapanış (TRY)" olarak yeniden adlandırınız.

# %%
 B30= B30[['Adj Close']]

 B30.columns=['Kapanış (TRY)']
 B30
# Out:
#             Kapanış (TRY)
# Date
# 2021-01-04    1495.400024
# 2021-01-05    1489.599976
# 2021-01-06    1505.400024
# 2021-01-07    1522.199951
# 2021-01-08    1540.599976
# ...                   ...
# 2021-12-24    1891.300049
# 2021-12-27    1897.099976
# 2021-12-28    1850.500000
# 2021-12-29    1895.500000
# 2021-12-30    1863.699951
#
# [247 rows x 1 columns]

# %% [markdown]
# 4. Tabloya yeni sütun ekleme:<br>
# *   Tabloya yeni bir sütun ekleyerek Kapanış (TRY) değerlerini 1 Ocak 2021 tarihindeki kapanış değerine göre normalize ediniz (yani tüm değerleri 1 Ocak 2021 değerine bölünüz). Bu alana "Normalize" alanı diyebilirsiniz.<br>

# %%
norm =B30.iloc[0,0]
norm

B30['Normalize']=B30['Kapanış (TRY)']/norm
B30
# Out:
# <ipython-input-13-60b2f8c1e147>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B30['Normalize']=B30['Kapanış (TRY)']/norm
#             Kapanış (TRY)  Normalize
# Date
# 2021-01-04    1495.400024   1.000000
# 2021-01-05    1489.599976   0.996121
# 2021-01-06    1505.400024   1.006687
# 2021-01-07    1522.199951   1.017922
# 2021-01-08    1540.599976   1.030226
# ...                   ...        ...
# 2021-12-24    1891.300049   1.264745
# 2021-12-27    1897.099976   1.268624
# 2021-12-28    1850.500000   1.237462
# 2021-12-29    1895.500000   1.267554
# 2021-12-30    1863.699951   1.246289
#
# [247 rows x 2 columns]

# %% [markdown]
# 5. Grafik çizdirme ve yorumlama:
# *   Tabloyu px.line grafiği olarak görselleştiriniz.<br>
# *   BIST30 endeksinin 2021 yılı boyunca değişimini yorumlayınız.

# %%
px.line(B30, y='Normalize')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9dcb4810-e203-4515-af6b-049b191a995f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dcb4810-e203-4515-af6b-049b191a995f")) {                    Plotly.newPlot(                        "9dcb4810-e203-4515-af6b-049b191a995f",                        [{"hovertemplate":"Date=%{x}<br>Normalize=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00"," ...

# %% [markdown]
# 6. Değişim alanlarını ekleme ve grafikte koşullu renklendirme:<br>
# 	• Normalize etiğiniz alan için her satırda bir önceki satırdaki Normalize değeri ile olan farkını hesaplattırınız (bu sütunu "degisim" olarak isimlendirebilirsiniz).
# 	• Tabloyu px.bar grafiği olarak görselleştiriniz.<br>
# 	• px.bar grafiğinde endeksin yükseldiği günleri "yeşil", düştüğü günleri "kırmızı" olarak görselleştiriniz.

# %%
B30['degisim']= B30['Normalize'].diff(1)

B30['d_yon']=B30['degisim'].map(lambda x:'düsen gün'if x<0 else 'yükselen gün')
# Out:
# <ipython-input-18-ea5189d179e1>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-18-ea5189d179e1>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
B30['degisim%']=(B30['degisim']/B30['Normalize'].shift(1))*100
# Out:
# <ipython-input-33-7bad1573e9c8>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
px.bar(B30, y='degisim%', 
       color='d_yon',color_discrete_map={'düsen gün':'red','yükselen gün':'green'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bcd703f3-ff77-4174-8dba-02352292450e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcd703f3-ff77-4174-8dba-02352292450e")) {                    Plotly.newPlot(                        "bcd703f3-ff77-4174-8dba-02352292450e",                        [{"alignmentgroup":"True","hovertemplate":"d_yon=y\u00fckselen g\u00fcn<br>Date=%{x}<br>degisim%=%{y}<extra></extra>","legendgroup":"y\u00fckselen g\u00fcn","marker":{"color":"green","pattern":{"shape":""}},"name":"y\u00fckselen g\u00fcn","offsetgroup":"y\u00fckselen g\u00fcn","orientation":"v","showlegend":true,"textposition":"auto","x":["2021-01-04T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-28T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-15T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-25T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-12T00:00:00","2021-03-16T00:00:00","2021-03-24T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-16T00:00:00","2021-04-22T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-29T00:00:00","2021-05-03T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-26T00:00:00","2021-05-28T00:00:00","2021-06-01T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-24T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-07T00:00:00","2021-07-09T00:00:00","2021-07-14T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-10T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-27T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-06T00:00:00","2021-09-09T00:00:00","2021-09-17T00:00:00","2021-09-22T00:00:00","2021-09-27T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-11-01T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","2021-11-12T00:00:00","2021-11-15T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-19T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-25T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-2 ...

# %% [markdown]
# 7. Histogram çizmek:
#
# *   px.histogram grafiğini çizdiriniz.
# *   Bölüm sayısını (nbins) nasıl belirlediniz,açıklayınız.
# *   Elde ettiğiniz grafiği yorumlayınız.

# %%
px.histogram(B30['degisim%'],nbins = 60)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id