# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraogz/GMKA_DILARA_OGUZ/blob/main/Python_%C3%96devi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install yfinance

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup as bs

import warnings
warnings.filterwarnings("ignore")

# %%
url = "https://www.isyatirim.com.tr/tr-tr/analiz/hisse/Sayfalar/Temel-Degerler-Ve-Oranlar.aspx?endeks=01#page-1"
     

response  = requests.get(url)

soup = bs(response.text, "html.parser")
table = soup.find("table", {"id": "summaryBasicData"})
tablo = pd.read_html(str(table))
tablo = pd.DataFrame(tablo[0])
tablo
# Out:
#       Kod              Hisse Adı               Sektör Kapanış (TL)  \
# 0   AEFES           Anadolu Efes    Meşrubat / İçecek         7635
# 1   AGHOL  Anadolu Grubu Holding           Holdingler        10510
# 2   AKBNK                 Akbank           Bankacılık         1929
# 3   AKFGY              Akfen GYO                  GYO          310
# 4    AKSA                   Aksa  Endüstriyel Tekstil         6180
# ..    ...                    ...                  ...          ...
# 95  VESBE      Vestel Beyaz Esya    Dayanıklı Tüketim         1047
# 96  VESTL      Vestel Elektronik    Dayanıklı Tüketim         3998
# 97  YKBNK     Yapı Kredi Bankası           Bankacılık         1163
# 98  YYLGD        Yayla Agro Gıda                 Gıda         2214
# 99  ZOREN           Zorlu Enerji             Elektrik          447
#
#    Piyasa Değeri (mn TL) Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 0               45.207,2              2.306,5                      329
# 1               25.595,5              1.305,9                      358
# 2              100.308,0              5.117,7                      518
# 3                4.030,0                 2056                      445
# 4               20.007,8              1.020,8                      353
# ..                   ...                  ...                      ...
# 95              16.752,0                 8547                      193
# 96              13.411,5                 6843                      399
# 97              98.239,2              5.012,2                      320
# 98              10.463,4                 5338                      150
# 99              11.175,0                 5701                      291
#
#    Sermaye (mn TL)
# 0             5921
# 1             2435
# 2          5.200,0
# 3          1.300,0
# 4             3238
# ..             ...
# 95         1.600,0
# 96            3355
# 97         8.447,1
# 98            4726
# 99         2.500,0
#
# [100 rows x 8 columns]

# %%
tablo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Kod                      100 non-null    object
#  1   Hisse Adı                100 non-null    object
#  2   Sektör                   100 non-null    object
#  3   Kapanış (TL)             100 non-null    object
#  4   Piyasa Değeri (mn TL)    100 non-null    object
#  5   Piyasa Değeri (mn $)     100 non-null    object
#  6   Halka Açıklık Oranı (%)  100 non-null    int64
#  7   Sermaye (mn TL)          100 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
tablo["Kapanış (TL)"] = tablo["Kapanış (TL)"].str.replace(".","")
tablo["Piyasa Değeri (mn TL)"] = tablo["Piyasa Değeri (mn TL)"].str.replace(".","")
tablo["Piyasa Değeri (mn $)"] = tablo["Piyasa Değeri (mn $)"].str.replace(".","")
tablo["Halka Açıklık Oranı (%)"] = tablo["Halka Açıklık Oranı (%)"]/10
tablo["Sermaye (mn TL)"] = tablo["Sermaye (mn TL)"].str.replace(".","")

tablo
# Out:
#       Kod              Hisse Adı               Sektör Kapanış (TL)  \
# 0   AEFES           Anadolu Efes    Meşrubat / İçecek         7635
# 1   AGHOL  Anadolu Grubu Holding           Holdingler        10510
# 2   AKBNK                 Akbank           Bankacılık         1929
# 3   AKFGY              Akfen GYO                  GYO          310
# 4    AKSA                   Aksa  Endüstriyel Tekstil         6180
# ..    ...                    ...                  ...          ...
# 95  VESBE      Vestel Beyaz Esya    Dayanıklı Tüketim         1047
# 96  VESTL      Vestel Elektronik    Dayanıklı Tüketim         3998
# 97  YKBNK     Yapı Kredi Bankası           Bankacılık         1163
# 98  YYLGD        Yayla Agro Gıda                 Gıda         2214
# 99  ZOREN           Zorlu Enerji             Elektrik          447
#
#    Piyasa Değeri (mn TL) Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 0                45207,2               2306,5                     32.9
# 1                25595,5               1305,9                     35.8
# 2               100308,0               5117,7                     51.8
# 3                 4030,0                 2056                     44.5
# 4                20007,8               1020,8                     35.3
# ..                   ...                  ...                      ...
# 95               16752,0                 8547                     19.3
# 96               13411,5                 6843                     39.9
# 97               98239,2               5012,2                     32.0
# 98               10463,4                 5338                     15.0
# 99               11175,0                 5701                     29.1
#
#    Sermaye (mn TL)
# 0             5921
# 1             2435
# 2           5200,0
# 3           1300,0
# 4             3238
# ..             ...
# 95          1600,0
# 96            3355
# 97          8447,1
# 98            4726
# 99          2500,0
#
# [100 rows x 8 columns]

# %%
tablo["Kapanış (TL)"] = tablo["Kapanış (TL)"].str.replace(",",".")
tablo["Piyasa Değeri (mn TL)"] = tablo["Piyasa Değeri (mn TL)"].str.replace(",",".")
tablo["Piyasa Değeri (mn $)"] = tablo["Piyasa Değeri (mn $)"].str.replace(",",".")
tablo["Sermaye (mn TL)"] = tablo["Sermaye (mn TL)"].str.replace(",",".")

tablo
# Out:
#       Kod              Hisse Adı               Sektör Kapanış (TL)  \
# 0   AEFES           Anadolu Efes    Meşrubat / İçecek         7635
# 1   AGHOL  Anadolu Grubu Holding           Holdingler        10510
# 2   AKBNK                 Akbank           Bankacılık         1929
# 3   AKFGY              Akfen GYO                  GYO          310
# 4    AKSA                   Aksa  Endüstriyel Tekstil         6180
# ..    ...                    ...                  ...          ...
# 95  VESBE      Vestel Beyaz Esya    Dayanıklı Tüketim         1047
# 96  VESTL      Vestel Elektronik    Dayanıklı Tüketim         3998
# 97  YKBNK     Yapı Kredi Bankası           Bankacılık         1163
# 98  YYLGD        Yayla Agro Gıda                 Gıda         2214
# 99  ZOREN           Zorlu Enerji             Elektrik          447
#
#    Piyasa Değeri (mn TL) Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 0                45207.2               2306.5                     32.9
# 1                25595.5               1305.9                     35.8
# 2               100308.0               5117.7                     51.8
# 3                 4030.0                 2056                     44.5
# 4                20007.8               1020.8                     35.3
# ..                   ...                  ...                      ...
# 95               16752.0                 8547                     19.3
# 96               13411.5                 6843                     39.9
# 97               98239.2               5012.2                     32.0
# 98               10463.4                 5338                     15.0
# 99               11175.0                 5701                     29.1
#
#    Sermaye (mn TL)
# 0             5921
# 1             2435
# 2           5200.0
# 3           1300.0
# 4             3238
# ..             ...
# 95          1600.0
# 96            3355
# 97          8447.1
# 98            4726
# 99          2500.0
#
# [100 rows x 8 columns]

# %%
tablo["Kapanış (TL)"] = tablo["Kapanış (TL)"].astype(float)
tablo["Kapanış (TL)"] = tablo["Kapanış (TL)"]/100

tablo["Piyasa Değeri (mn TL)"] = tablo["Piyasa Değeri (mn TL)"].astype(float)
tablo["Piyasa Değeri (mn $)"] = tablo["Piyasa Değeri (mn $)"].astype(float)
tablo["Sermaye (mn TL)"] = tablo["Sermaye (mn TL)"].astype(float)

tablo
# Out:
#       Kod              Hisse Adı               Sektör  Kapanış (TL)  \
# 0   AEFES           Anadolu Efes    Meşrubat / İçecek         76.35
# 1   AGHOL  Anadolu Grubu Holding           Holdingler        105.10
# 2   AKBNK                 Akbank           Bankacılık         19.29
# 3   AKFGY              Akfen GYO                  GYO          3.10
# 4    AKSA                   Aksa  Endüstriyel Tekstil         61.80
# ..    ...                    ...                  ...           ...
# 95  VESBE      Vestel Beyaz Esya    Dayanıklı Tüketim         10.47
# 96  VESTL      Vestel Elektronik    Dayanıklı Tüketim         39.98
# 97  YKBNK     Yapı Kredi Bankası           Bankacılık         11.63
# 98  YYLGD        Yayla Agro Gıda                 Gıda         22.14
# 99  ZOREN           Zorlu Enerji             Elektrik          4.47
#
#     Piyasa Değeri (mn TL)  Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 0                 45207.2                2306.5                     32.9
# 1                 25595.5                1305.9                     35.8
# 2                100308.0                5117.7                     51.8
# 3                  4030.0                2056.0                     44.5
# 4                 20007.8                1020.8                     35.3
# ..                    ...                   ...                      ...
# 95                16752.0                8547.0                     19.3
# 96                13411.5                6843.0                     39.9
# 97                98239.2                5012.2                     32.0
# 98                10463.4                5338.0                     15.0
# 99                11175.0                5701.0                     29.1
#
#     Sermaye (mn TL)
# 0            5921.0
# 1            2435.0
# 2            5200.0
# 3            1300.0
# 4            3238.0
# ..              ...
# 95           1600.0
# 96           3355.0
# 97           8447.1
# 98           4726.0
# 99           2500.0
#
# [100 rows x 8 columns]

# %%
tablo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Kod                      100 non-null    object
#  1   Hisse Adı                100 non-null    object
#  2   Sektör                   100 non-null    object
#  3   Kapanış (TL)             100 non-null    float64
#  4   Piyasa Değeri (mn TL)    100 non-null    float64
#  5   Piyasa Değeri (mn $)     100 non-null    float64
#  6   Halka Açıklık Oranı (%)  100 non-null    float64
#  7   Sermaye (mn TL)          100 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 6.4+ KB

# %%
temiz_tablo = tablo.copy()
temiz_tablo
# Out:
#       Kod              Hisse Adı               Sektör  Kapanış (TL)  \
# 0   AEFES           Anadolu Efes    Meşrubat / İçecek         76.35
# 1   AGHOL  Anadolu Grubu Holding           Holdingler        105.10
# 2   AKBNK                 Akbank           Bankacılık         19.29
# 3   AKFGY              Akfen GYO                  GYO          3.10
# 4    AKSA                   Aksa  Endüstriyel Tekstil         61.80
# ..    ...                    ...                  ...           ...
# 95  VESBE      Vestel Beyaz Esya    Dayanıklı Tüketim         10.47
# 96  VESTL      Vestel Elektronik    Dayanıklı Tüketim         39.98
# 97  YKBNK     Yapı Kredi Bankası           Bankacılık         11.63
# 98  YYLGD        Yayla Agro Gıda                 Gıda         22.14
# 99  ZOREN           Zorlu Enerji             Elektrik          4.47
#
#     Piyasa Değeri (mn TL)  Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 0                 45207.2                2306.5                     32.9
# 1                 25595.5                1305.9                     35.8
# 2                100308.0                5117.7                     51.8
# 3                  4030.0                2056.0                     44.5
# 4                 20007.8                1020.8                     35.3
# ..                    ...                   ...                      ...
# 95                16752.0                8547.0                     19.3
# 96                13411.5                6843.0                     39.9
# 97                98239.2                5012.2                     32.0
# 98                10463.4                5338.0                     15.0
# 99                11175.0                5701.0                     29.1
#
#     Sermaye (mn TL)
# 0            5921.0
# 1            2435.0
# 2            5200.0
# 3            1300.0
# 4            3238.0
# ..              ...
# 95           1600.0
# 96           3355.0
# 97           8447.1
# 98           4726.0
# 99           2500.0
#
# [100 rows x 8 columns]

# %%
temiz_tablo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Kod                      100 non-null    object
#  1   Hisse Adı                100 non-null    object
#  2   Sektör                   100 non-null    object
#  3   Kapanış (TL)             100 non-null    float64
#  4   Piyasa Değeri (mn TL)    100 non-null    float64
#  5   Piyasa Değeri (mn $)     100 non-null    float64
#  6   Halka Açıklık Oranı (%)  100 non-null    float64
#  7   Sermaye (mn TL)          100 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 6.4+ KB

# %% [markdown]
# # Bist 100 Yapısının İncelenmesi

# %%
top10 = temiz_tablo.sort_values('Piyasa Değeri (mn TL)', ascending=False).head(10)
top10
# Out:
#       Kod                   Hisse Adı                Sektör  Kapanış (TL)  \
# 52  KCHOL                 Koç Holding            Holdingler         96.85
# 72   SASA  Sasa Polyester Sanayi A.Ş.   Endüstriyel Tekstil         95.60
# 35  FROTO                 Ford Otosan              Otomotiv        561.30
# 81  THYAO           Türk Hava Yolları  Havayolları ve Hizm.        132.60
# 30  ENKAI                 Enka İnşaat       İnşaat- Taahhüt         24.30
# 46  ISCTR              İş Bankası (C)            Bankacılık         13.97
# 36  GARAN             Garanti Bankası            Bankacılık         33.10
# 90  TUPRS                      Tüpraş                Petrol         71.00
# 74   SISE                     Şişecam                   Cam         39.86
# 32  EREGL          Ereğli Demir Çelik     Demir-Çelik Temel         30.80
#
#     Piyasa Değeri (mn TL)  Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 52               245601.7               12530.6                     26.4
# 72               220127.7               11230.9                     23.0
# 35               196965.8               10049.2                     17.8
# 81               182988.0                9336.0                     50.3
# 30               145800.0                7438.7                      8.9
# 46               139699.6                7127.5                     33.5
# 36               139020.0                7092.8                     14.0
# 90               136802.5                6979.6                     46.5
# 74               122099.7                6229.5                     48.9
# 32               107800.0                5499.9                     47.5
#
#     Sermaye (mn TL)
# 52           2535.9
# 72           2302.6
# 35           3509.0
# 81           1380.0
# 30           6000.0
# 46          10000.0
# 36           4200.0
# 90           1926.8
# 74           3063.2
# 32           3500.0

# %%
fig_1 = px.bar(top10, x=top10['Hisse Adı'], y=top10['Piyasa Değeri (mn TL)'],
        width=1000, height=500,
        title = "Piyasa Değeri En Yüksek İlk 10 Şirket",
        hover_data = {"Hisse Adı": "::", "Piyasa Değeri (mn TL)": ":.2f","Sektör": "::",},
        )

fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8c3c3f43-2260-4f0b-99f4-b2707a644470" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c3c3f43-2260-4f0b-99f4-b2707a644470")) {                    Plotly.newPlot(                        "8c3c3f43-2260-4f0b-99f4-b2707a644470",                        [{"alignmentgroup":"True","customdata":[["Holdingler"],["End\u00fcstriyel Tekstil"],["Otomotiv"],["Havayollar\u0131 ve Hizm."],["\u0130n\u015faat- Taahh\u00fct"],["Bankac\u0131l\u0131k"],["Bankac\u0131l\u0131k"],["Petrol"],["Cam"],["Demir-\u00c7elik Temel"]],"hovertemplate":"Hisse Ad\u0131=%{x::}<br>Piyasa De\u011feri (mn TL)=%{y:.2f}<br>Sekt\u00f6r=%{customdata[0]::}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Ko\u00e7 Holding","Sasa Polyester Sanayi A.\u015e.","Ford Otosan","T\u00fcrk Hava Yollar\u0131","Enka \u0130n\u015faat","\u0130\u015f Bankas\u0131 (C)","Garanti Bankas\u0131","T\u00fcpra\u015f","\u015ei\u015fecam","Ere\u011fli Demir \u00c7elik"],"xaxis":"x","y":[245601.7,220127.7,196965.8,182988.0,145800.0,139699.6,139020.0,136802.5,122099.7,107800.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter" ...

# %%
sektörler = dict(temiz_tablo.groupby("Sektör").groups)
Sektörler = []
Piyasa_Degeri = []
for i in sektörler.keys():
  Sektörler.append(i)
  Piyasa_Degeri.append(temiz_tablo[temiz_tablo["Sektör"] == i]["Kapanış (TL)"].mean())

# %%
tablo2 = pd.DataFrame()
tablo2["Sektör İsimleri"] = Sektörler
tablo2["Piyasa Değerleri"] = Piyasa_Degeri
tablo2.head(4)
# Out:
#      Sektör İsimleri  Piyasa Değerleri
# 0         Bankacılık         12.026667
# 1                Cam         39.860000
# 2  Dayanıklı Tüketim         48.316667
# 3  Demir-Çelik Döküm         55.630000

# %%
tablo2 = pd.DataFrame()
tablo2["Sektör İsimleri"] = Sektörler
tablo2["Piyasa Değerleri"] = Piyasa_Degeri    
tablo2.head()
# Out:
#      Sektör İsimleri  Piyasa Değerleri
# 0         Bankacılık         12.026667
# 1                Cam         39.860000
# 2  Dayanıklı Tüketim         48.316667
# 3  Demir-Çelik Döküm         55.630000
# 4  Demir-Çelik Temel         21.243333

# %%
tablo2_sorted = tablo2.sort_values('Piyasa Değerleri', ascending=False)

fig = px.bar(tablo2_sorted, x="Sektör İsimleri", y="Piyasa Değerleri",text_auto='.2s',
              hover_data=['Sektör İsimleri', 'Piyasa Değerleri'], color='Piyasa Değerleri',width=1000, height=500,
        title="Sektör Bazlı Şirketlerin Piyasa Değerleri ortalaması",)

fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1025edce-b1c5-4851-9ba6-efe30c655866" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1025edce-b1c5-4851-9ba6-efe30c655866")) {                    Plotly.newPlot(                        "1025edce-b1c5-4851-9ba6-efe30c655866",                        [{"alignmentgroup":"True","hovertemplate":"Sekt\u00f6r \u0130simleri=%{x}<br>Piyasa De\u011ferleri=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[311.5025,212.25,180.575,119.875,112.4,103.4375,89.16000000000001,73.25,55.63,49.79923076923077,48.84,48.31666666666666,46.62,42.292,41.75,41.26,39.86,35.31225,32.199999999999996,25.72,25.560000000000002,24.16,21.243333333333336,19.466,12.026666666666666,10.08,6.626666666666666],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","texttemplate":"%{y:.2s}","x":["Otomotiv","Havayollar\u0131 ve Hizm.","Me\u015frubat / \u0130\u00e7ecek","Holdingler","Tekstil Entegre","Perakande - Ticaret","Tar\u0131m Kimyasallar\u0131","End\u00fcstriyel Tekstil","Demir-\u00c7elik D\u00f6k\u00fcm","Elektrik","Kimyasal \u00dcr\u00fcn","Dayan\u0131kl\u0131 T\u00fcketim","Spor","Otomotiv Par\u00e7as\u0131","Petrol","Savunma","Cam","\u00c7imento","Sa\u011fl\u0131k ve \u0130la\u00e7","\u0130n\u015faat- Taahh\u00fct","Madencilik","\u0130leti\u015fim","Demir-\u00c7elik Temel","G\u0131da","Bankac\u0131l\u0131k","Sigorta","GYO"],"xaxis":"x","y":[311.5025,212.25,180.575,119.875,112.4,103.4375,89.16000000000001,73.25,55.63,49.79923076923077,48.84,48.31666666666666,46.62,42.292,41.75,41.26,39.86,35.31225,32.199999999999996,25.72,25.560000000000002,24.16,21.243333333333336,19.466,12.026666666666666,10.08,6.626666666666666],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...

# %% [markdown]
# # Şireketlerin Analizi:

# %%
# Verileri indirin ve her şirket için ayrı bir değişkene kaydedin
SKBNKC_data = yf.download('SKBNK.IS', start='2022-01-01', end='2022-12-31')
TSKB_data = yf.download('TSKB.IS', start='2022-01-01', end='2022-12-31')
TCELL_data = yf.download('TCELL.IS', start='2022-01-01', end='2022-12-31')
TTKOM_data = yf.download('TTKOM.IS', start='2022-01-01', end='2022-12-31')
TURSG_data = yf.download('TURSG.IS', start='2022-01-01', end='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
SKBNKC_data.head(3)
# Out:
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2022-01-03  1.02  1.06  1.01   1.06   1.035934   74102746
# 2022-01-04  1.06  1.11  1.05   1.07   1.045707  121781629
# 2022-01-05  1.07  1.08  1.06   1.07   1.045707   41437183

# %%
TSKB_data.head(3)
# Out:
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2022-01-03  1.44  1.50  1.44   1.48       1.48   88941032
# 2022-01-04  1.50  1.52  1.46   1.48       1.48  111624268
# 2022-01-05  1.48  1.51  1.47   1.50       1.50   81812307

# %%
TCELL_data.head(3)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  18.760000  19.299999  18.620001  19.090000  18.476162  5656518
# 2022-01-04  19.260000  19.750000  18.969999  19.639999  19.008476  9426542
# 2022-01-05  19.639999  20.180000  19.320000  20.160000  19.511757  9894682

# %%
TTKOM_data.head(3)
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2022-01-03   9.71  10.10   9.64   9.92   8.792076  21174279
# 2022-01-04   9.97  10.29   9.93  10.18   9.022514  25375454
# 2022-01-05  10.23  10.90  10.14  10.86   9.625196  37446851

# %%
TURSG_data.head(3)
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2022-01-03  5.08  5.16  5.05   5.15   4.750868   8471218
# 2022-01-04  5.20  5.21  5.06   5.16   4.760093  10972778
# 2022-01-05  5.16  5.17  5.10   5.16   4.760093   8623818

# %%
# Semboller listesi
symbols = ['SKBNK.IS', 'TCELL.IS', 'TSKB.IS', 'TTKOM.IS', 'TURSG.IS', "XU100.IS"]

# Verileri al
data = yf.download(symbols, start='2022-01-01', end='2022-12-31', interval='1d', group_by='ticker')
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
# Her hisse senedi için ayrı bir veri çerçevesi oluştur
skbnk = data['SKBNK.IS']
tcell = data['TCELL.IS']
tskb = data['TSKB.IS']
ttkom = data['TTKOM.IS']
tursg = data['TURSG.IS']
bist100 = data['XU100.IS']

skbnk = skbnk[['Adj Close']]
tcell = tcell[['Adj Close']]
tskb = tskb[['Adj Close']]
ttkom = ttkom[['Adj Close']]
tursg = tursg[['Adj Close']]
bist100 = bist100[['Adj Close']]

skbnk["Normalize"] = skbnk[['Adj Close']] / skbnk.iloc[0,0]
tcell["Normalize"] = tcell[['Adj Close']]/ tcell.iloc[0,0]
tskb["Normalize"] = tskb[['Adj Close']]/tskb.iloc[0,0]
ttkom["Normalize"] = ttkom[['Adj Close']]/ttkom.iloc[0,0]
tursg["Normalize"] = tursg[['Adj Close']]/tursg.iloc[0,0]
bist100["Normalize"] = bist100[['Adj Close']]/bist100.iloc[0,0]

# %%
tablo3 = pd.DataFrame()
tablo3["Bist100 Normalize"] = bist100["Normalize"]
tablo3["Şeker Bank Normalize"] = tcell["Normalize"]
tablo3["Turcell Normalize"] = bist100["Normalize"]
tablo3["Türk Telekom Normalize"] = ttkom["Normalize"]
tablo3["Türkiye Sigorta Normalize"] = tursg["Normalize"]
tablo3["Türkiye Sınai Kalkınma Bankası Normalize"] = tskb["Normalize"]
tablo3.head(3)
# Out:
#             Bist100 Normalize  Şeker Bank Normalize  Turcell Normalize  \
# Date
# 2022-01-03           1.000000              1.000000           1.000000
# 2022-01-04           1.019152              1.028811           1.019152
# 2022-01-05           1.040795              1.056050           1.040795
#
#             Türk Telekom Normalize  Türkiye Sigorta Normalize  \
# Date
# 2022-01-03                1.000000                   1.000000
# 2022-01-04                1.026210                   1.001942
# 2022-01-05                1.094758                   1.001942
#
#             Türkiye Sınai Kalkınma Bankası Normalize
# Date
# 2022-01-03                                  1.000000
# 2022-01-04                                  1.000000
# 2022-01-05                                  1.013514

# %%
fig_1 = px.line(tablo3, y=["Bist100 Normalize","Şeker Bank Normalize","Turcell Normalize","Türk Telekom Normalize", "Türkiye Sigorta Normalize","Türkiye Sınai Kalkınma Bankası Normalize"],
        width=1000, height=500,
        title = "Hisse Senetleri Performansı",
        labels = {"Bist100": bist100['Normalize']}
        )

fig_1.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="33ba1fa4-02fd-4d36-a256-a80f9c2e3ab3" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33ba1fa4-02fd-4d36-a256-a80f9c2e3ab3")) {                    Plotly.newPlot(                        "33ba1fa4-02fd-4d36-a256-a80f9c2e3ab3",                        [{"hovertemplate":"variable=Bist100 Normalize<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Bist100 Normalize","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bist100 Normalize","showlegend":true,"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-20T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","2022-06-03T00:00:00","2022-06-06T00:00:00","2022-06-07T00:00:00","2022-06-08T00:00:00","2022-06-09T00:00:00","2022-06-10T00:00:00","2022-06-13T00:00:00","2022-06-14T00:00:00","2022-06-15T00:00:00","2022-06-16T00:00:00","2022-06-17T00:00:00","2022-06-20T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-24T00:00:00","2022-06-27T00:00:00","2022-06-28T00:00:00","2022-06-29T00:00:00","2022-06-30T00:00:00","2022-07-01T00:00:00","2022-07-04T00:00:00","2022-07-05T00:00:00","2022-07-06T00:00:00","2022-07-07T00:00:00","2022-07-08T00:00:00","2022-07-13T00:00:00","2022-07-14T00:00:00","2022-07-18T00:00:00","2022-07-19T00:00:00","2022-07-20T00:00:00","2022-07-21T00:00:00","2022-07-22T00:00:00","2022-07-25T00:00:00","2022-07-26T00:00:00","2022-07-27T00:00:00","2022-07-28T00:00:00","2022-07-29T00:00:00","2022-08-01T00:00:00","2022-08-02T00:00:00","2 ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 10))

plt.subplot(3, 2, 1)
plt.plot(bist100['Normalize'], label='BIST100', color="red")
plt.plot(skbnk['Normalize'], label='SKBNK', color="green")
plt.legend()
plt.grid()

plt.subplot(3, 2, 2)
plt.plot(bist100['Normalize'], label='BIST100', color="red")
plt.plot(tcell['Normalize'], label='TCELL', color="yellow")
plt.legend()
plt.grid()

plt.subplot(3, 2, 3)
plt.plot(bist100['Normalize'], label='BIST100', color="red")
plt.plot(tskb['Normalize'], label='TSKB', color="black")
plt.legend()
plt.grid()

plt.subplot(3, 2, 4)
plt.plot(bist100['Normalize'], label='BIST100', color="red")
plt.plot(ttkom['Normalize'], label='TTKOM', color="darkblue")
plt.legend()
plt.grid()

plt.subplot(3, 2, 5)
plt.plot(bist100['Normalize'], label='BIST100', color="red")
plt.plot(tursg['Normalize'], label='TURSG', color="aqua")
plt.legend()
plt.grid()

plt.show()

# %%
symbols = ['SKBNK', 'TCELL', 'TSKB', 'TTKOM', 'TURSG']
deger = []
hisse_adı = []
for i in symbols:
    deger.append(temiz_tablo[temiz_tablo["Kod"] == i]["Piyasa Değeri (mn TL)"].values[0])
    hisse_adı.append(temiz_tablo[temiz_tablo["Kod"] == i]["Hisse Adı"].values[0])

bist5 = pd.DataFrame()
bist5["Kod"] = symbols
bist5["Hisse Adı"] = hisse_adı
bist5["Piyasa Değeri (mn TL)"] = deger
bist5
# Out:
#      Kod        Hisse Adı  Piyasa Değeri (mn TL)
# 0  SKBNK        Şekerbank                 4371.0
# 1  TCELL         Turkcell                75900.0
# 2   TSKB             TSKB                12348.0
# 3  TTKOM     Türk Telekom                48370.0
# 4  TURSG  Türkiye Sigorta                11708.2

# %%
tablo3
# Out:
#             Bist100 Normalize  Şeker Bank Normalize  Turcell Normalize  \
# Date
# 2022-01-03           1.000000              1.000000           1.000000
# 2022-01-04           1.019152              1.028811           1.019152
# 2022-01-05           1.040795              1.056050           1.040795
# 2022-01-06           1.041989              1.031954           1.041989
# 2022-01-07           1.055328              1.021477           1.055328
# ...                       ...                   ...                ...
# 2022-12-26           2.856750              2.024230           2.856750
# 2022-12-27           2.820626              2.090261           2.820626
# 2022-12-28           2.774485              2.002580           2.774485
# 2022-12-29           2.842633              2.067529           2.842633
# 2022-12-30           2.859397              2.050209           2.859397
#
#             Türk Telekom Normalize  Türkiye Sigorta Normalize  \
# Date
# 2022-01-03                1.000000                   1.000000
# 2022-01-04                1.026210                   1.001942
# 2022-01-05                1.094758                   1.001942
# 2022-01-06                1.085686                   0.998058
# 2022-01-07                1.077621                   1.000000
# ...                            ...                        ...
# 2022-12-26                2.415812                   2.744761
# 2022-12-27                2.452208                   2.799488
# 2022-12-28                2.402163                   2.685825
# 2022-12-29                2.641014                   2.692139
# 2022-12-30                2.793424                   2.635308
#
#             Türkiye Sınai Kalkınma Bankası Normalize
# Date
# 2022-01-03                                  1.000000
# 2022-01-04                                  1.000000
# 2022-01-05                                  1.013514
# 2022-01-06                                  1.020270
# 2022-01-07                                  1.060811
# ...                                              ...
# 2022-12-26                                  3.128378
# 2022-12-27                                  3.020270
# 2022-12-28                                  2.878378
# 2022-12-29                                  2.952703
# 2022-12-30                                  2.952703
#
# [252 rows x 6 columns]

# %%
bist5 = tablo3.copy()
bist5 = bist5.drop(["Bist100 Normalize"], axis=1) # sütun silme
bist5["Bist5"] = bist5.mean(axis=1)
bist5 = bist5.drop(["Şeker Bank Normalize","Turcell Normalize","Türk Telekom Normalize","Türkiye Sigorta Normalize","Türkiye Sınai Kalkınma Bankası Normalize"], axis=1) # sütun silme
bist5
# Out:
#                Bist5
# Date
# 2022-01-03  1.000000
# 2022-01-04  1.015223
# 2022-01-05  1.041412
# 2022-01-06  1.035591
# 2022-01-07  1.043047
# ...              ...
# 2022-12-26  2.633986
# 2022-12-27  2.636571
# 2022-12-28  2.548686
# 2022-12-29  2.639204
# 2022-12-30  2.658208
#
# [252 rows x 1 columns]

# %%
bist100 = bist100.drop(["Adj Close"], axis=1) # sütun silme
bist100
# Out:
#             Normalize
# Date
# 2022-01-03   1.000000
# 2022-01-04   1.019152
# 2022-01-05   1.040795
# 2022-01-06   1.041989
# 2022-01-07   1.055328
# ...               ...
# 2022-12-26   2.856750
# 2022-12-27   2.820626
# 2022-12-28   2.774485
# 2022-12-29   2.842633
# 2022-12-30   2.859397
#
# [252 rows x 1 columns]

# %%
bist5_bist100 = pd.DataFrame(index = bist5.index)
bist5_bist100["Bist5"] = bist5
bist5_bist100["Bist100"] = bist100
bist5_bist100
# Out:
#                Bist5   Bist100
# Date
# 2022-01-03  1.000000  1.000000
# 2022-01-04  1.015223  1.019152
# 2022-01-05  1.041412  1.040795
# 2022-01-06  1.035591  1.041989
# 2022-01-07  1.043047  1.055328
# ...              ...       ...
# 2022-12-26  2.633986  2.856750
# 2022-12-27  2.636571  2.820626
# 2022-12-28  2.548686  2.774485
# 2022-12-29  2.639204  2.842633
# 2022-12-30  2.658208  2.859397
#
# [252 rows x 2 columns]

# %%
fig_1 = px.line(bist5_bist100, y=["Bist100","Bist5"],
        width=1000, height=500,
        title = "Hisse Senetleri Performansı",
        )

fig_1.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="98d96855-b1d1-469b-963a-c6496786a53a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98d96855-b1d1-469b-963a-c6496786a53a")) {                    Plotly.newPlot(                        "98d96855-b1d1-469b-963a-c6496786a53a",                        [{"hovertemplate":"variable=Bist100<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Bist100","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bist100","orientation":"v","showlegend":true,"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-20T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","2022-06-03T00:00:00","2022-06-06T00:00:00","2022-06-07T00:00:00","2022-06-08T00:00:00","2022-06-09T00:00:00","2022-06-10T00:00:00","2022-06-13T00:00:00","2022-06-14T00:00:00","2022-06-15T00:00:00","2022-06-16T00:00:00","2022-06-17T00:00:00","2022-06-20T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-24T00:00:00","2022-06-27T00:00:00","2022-06-28T00:00:00","2022-06-29T00:00:00","2022-06-30T00:00:00","2022-07-01T00:00:00","2022-07-04T00:00:00","2022-07-05T00:00:00","2022-07-06T00:00:00","2022-07-07T00:00:00","2022-07-08T00:00:00","2022-07-13T00:00:00","2022-07-14T00:00:00","2022-07-18T00:00:00","2022-07-19T00:00:00","2022-07-20T00:00:00","2022-07-21T00:00:00","2022-07-22T00:00:00","2022-07-25T00:00:00","2022-07-26T00:00:00","2022-07-27T00:00:00","2022-07-28T00:00:00","2022-07-29T00:00:00","2022-08-01T00:00:00","2022-08-02T00:00:00","2022-08-03T00 ...
